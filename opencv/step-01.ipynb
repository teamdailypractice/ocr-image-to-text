# %% [markdown]
#  ## Opening an image

# %%
import os
import sys

# def set_venv_to_syspath():
#     venv_path = os.path.join(os.getcwd(), "venv", "lib","site-packages")
#     print(venv_path);
#     sys.path.insert(0,venv_path)
#     print(sys.path)


# set_venv_to_syspath()
print(sys.path)
# Out:
# ['d:\\git\\ocr-image-to-text\\opencv', 'c:\\Users\\venkatasubban\\anaconda3\\envs\\tamil-pdf-ocr\\python310.zip', 'c:\\Users\\venkatasubban\\anaconda3\\envs\\tamil-pdf-ocr\\DLLs', 'c:\\Users\\venkatasubban\\anaconda3\\envs\\tamil-pdf-ocr\\lib', 'c:\\Users\\venkatasubban\\anaconda3\\envs\\tamil-pdf-ocr', '', 'c:\\Users\\venkatasubban\\anaconda3\\envs\\tamil-pdf-ocr\\lib\\site-packages', 'c:\\Users\\venkatasubban\\anaconda3\\envs\\tamil-pdf-ocr\\lib\\site-packages\\win32', 'c:\\Users\\venkatasubban\\anaconda3\\envs\\tamil-pdf-ocr\\lib\\site-packages\\win32\\lib', 'c:\\Users\\venkatasubban\\anaconda3\\envs\\tamil-pdf-ocr\\lib\\site-packages\\Pythonwin']

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt

image_file = "data/page_01.jpg"
img = cv2.imread(image_file)

# cv2.imshow("original image", img)
# cv2.waitKey(5000)

# %%
def display_image_in_actual_size(im_path):

    dpi = 80
    im_data = plt.imread(im_path)
    height, width, depth = im_data.shape

    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show(img)

# %%
from calendar import c


def show_image(image_filepath):
    print("displaying image: " + image_filepath)
    
    img_data = plt.imread(image_filepath)
    # print(type(img_data))
    # print (img_data.shape)
    height, width, depth = img_data.shape

    dpi = 80
       # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')
    # ax.imshow(img_data, cmap="gray")
    plt.imshow(img_data, cmap=plt.cm.gray)
    
try:
  show_image(image_file)
except:
  print("is it fine?")
# Out:
# displaying image: data/page_01.jpg
# <class 'numpy.ndarray'>
# (1522, 1200, 3)
